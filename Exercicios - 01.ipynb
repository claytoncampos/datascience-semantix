# %% [markdown]
# ### Exercicio
# 01 -Importe a função randint da biblioteca numpy

# %%
 from numpy.random import randint

# %% [markdown]
# 02 - Crie uma lista de números 15 números aleatórios inteiros, que estejam entre 0 e 10, usando a função randint e o método append de uma lista.

# %%
inteiros_15 = []
for i in range(15):
    inteiros_15.append(randint(10))

# %%
print(inteiros_15)
# Out:
# [4, 4, 6, 8, 3, 6, 9, 1, 5, 1, 0, 4, 5, 3, 5]

# %%
len(inteiros_15)
# Out:
# 15

# %% [markdown]
# 03 - Adicione o comando %%timeit no topo da célula que você criou para a função 2, ele irá calcular o tempo médio de execução do seu código

# %%
# %%timeit
inteiros_15 = []
for i in range(15):
    inteiros_15.append(randint(10))
# Out:
# 32.3 µs ± 2.33 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
#  04 -Use os argumentos size e type na função randint para repetir a questão 2.

# %%
#numpy trabalha com arrays
randint(11, size=15)
# Out:
# array([10,  1,  5,  3,  3,  9,  6,  2, 10,  5,  7,  9,  5,  7,  6])

# %%
type(inteiros_15)
# Out:
# list

# %%
list(randint(11, size=15))
# Out:
# [6, 7, 5, 0, 10, 6, 0, 0, 3, 4, 0, 6, 3, 8, 5]

# %% [markdown]
# 05 - Calcule o tempo do código feito na questão 4. É menor que o da questão 03?

# %%
# %%timeit
randint(11, size=15)
# Out:
# 8.77 µs ± 385 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# 06 - Faça uma função com apenas for,range,len, while, if, else, break para ordenar a lista que você criou na questão 04 do menor para o maior número.

# %%
def verifica_se_ja_ordenou(lista):
    flag = True
    
    for i in range(len(lista)-1):
        if lista[i] > lista[i+1]:
            flag = False
            
    return flag

def organiza_elementos(lista):
    
    ordenado = []
    
    for i in range(len(lista)-1):
        if lista[i] > lista[i+1]:
            ordenado.append(lista[i+1])
            ordenado.append(lista[i])
            ordenado = ordenado + lista[i+2:]
            break
        else:
            ordenado.append(lista[i])
            
    return ordenado

def ordena_lista(lista, maximo=100):
    
    
    ordenado = lista
    
    for i in range(maximo):
        if verifica_se_ja_ordenou(ordenado):
            print('Lista Ordenada!')
            break
        else:
            ordenado = organiza_elementos(ordenado)
            print(ordenado)
    return ordenado

# %%
inteiros_15
# Out:
# [4, 4, 6, 8, 3, 6, 9, 1, 5, 1, 0, 4, 5, 3, 5]

# %%
verifica_se_ja_ordenou(inteiros_15)
# Out:
# False

# %%
organiza_elementos(inteiros_15)
# Out:
# [4, 4, 6, 3, 8, 6, 9, 1, 5, 1, 0, 4, 5, 3, 5]

# %%
ordena_lista(inteiros_15)
# Out:
# [4, 4, 6, 3, 8, 6, 9, 1, 5, 1, 0, 4, 5, 3, 5]
# [4, 4, 3, 6, 8, 6, 9, 1, 5, 1, 0, 4, 5, 3, 5]
# [4, 3, 4, 6, 8, 6, 9, 1, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 6, 8, 6, 9, 1, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 6, 6, 8, 9, 1, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 6, 6, 8, 1, 9, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 6, 6, 1, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 6, 1, 6, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 1, 6, 6, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 1, 4, 6, 6, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [3, 1, 4, 4, 6, 6, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 6, 6, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 6, 6, 8, 5, 9, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 6, 6, 5, 8, 9, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 6, 5, 6, 8, 9, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 5, 6, 6, 8, 9, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 5, 6, 6, 8, 1, 9, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 5, 6, 6, 1, 8, 9, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 5, 6, 1, 6, 8, 9, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 5, 1, 6, 6, 8, 9, 0, 4, 5, 3, 5]
# ...

# %% [markdown]
# 07 - Use a função sorted para refazer a questão 06

# %%
sorted(inteiros_15)
# Out:
# [0, 1, 1, 3, 3, 4, 4, 4, 5, 5, 5, 6, 6, 8, 9]

# %% [markdown]
# 08 - Calcule o tempo da questão 6 e da questão 07

# %%
# %%timeit
ordena_lista(inteiros_15)
# Out:
# [4, 4, 6, 3, 8, 6, 9, 1, 5, 1, 0, 4, 5, 3, 5]
# [4, 4, 3, 6, 8, 6, 9, 1, 5, 1, 0, 4, 5, 3, 5]
# [4, 3, 4, 6, 8, 6, 9, 1, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 6, 8, 6, 9, 1, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 6, 6, 8, 9, 1, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 6, 6, 8, 1, 9, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 6, 6, 1, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 6, 1, 6, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 4, 1, 6, 6, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [3, 4, 1, 4, 6, 6, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [3, 1, 4, 4, 6, 6, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 6, 6, 8, 9, 5, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 6, 6, 8, 5, 9, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 6, 6, 5, 8, 9, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 6, 5, 6, 8, 9, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 5, 6, 6, 8, 9, 1, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 5, 6, 6, 8, 1, 9, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 5, 6, 6, 1, 8, 9, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 5, 6, 1, 6, 8, 9, 0, 4, 5, 3, 5]
# [1, 3, 4, 4, 5, 1, 6, 6, 8, 9, 0, 4, 5, 3, 5]
# ...

# %%
# %%timeit
sorted(inteiros_15)
# Out:
# 447 ns ± 32.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
#forma correta de fazer copia
numeros2 = [1,2,3,4,5]
inteiros2 = numeros2.copy()

inteiros2.pop()

print(numeros2)
print(inteiros2)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4]
